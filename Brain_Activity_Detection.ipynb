# %% [markdown]
# # Harmful Brain Activity Detection

# %% [markdown]
# ## Approach
#
# Since the data is EEG and spectrogram data, we use signal processing methods for pre-processing and feature extraction and depending on the type of features we use an appropriate neural network for prediction
#
# ### Data Pre-Procssing
#
# * **Band Pass Filter**
# * **ICA**  - Artifact removal such as eye blinks, heart beats, muscle movements,.etc
#
# ### Feature Extraction
#
# * **Power Spectral Density** - time domain
# * **FFT** - Frequency domain
#
# * **Waveform** - Time-Frequency Domain
#
#
# ### Predictive Model
#
# * CNN for FFT
# * Vision Transformer
# * LSTM for Power Spectral Density
#
# ### Evaluation
#
# * Kullback Liebler divergence

# %%
import dask
import multiprocessing
import keras
import os
import pandas as pd
import scipy
from scipy.signal import butter, lfilter
from mne.preprocessing import ICA

# %%
# Path to files

path_eeg = "hms-harmful-brain-activity-classification/train_eegs/"
path_spec = "hms-harmful-brain-activity-classification/train_spectrograms/"
path_train_csv = "hms-harmful-brain-activity-classification/train.csv"
path_test_csv = "hms-harmful-brain-activity-classification/test.csv"

# %% [markdown]
# ### Read EEG and Spectrogram files

# %%
# Function to read eeg and spectrogram data
def read_file(folder):
    files = [os.path.join(folder, file) for file in os.listdir(folder)]
    return files

# %%
# EEG data frame
eeg_files = read_file(path_eeg)

# %%
# Read Spectrogram data
spec_files = read_file(path_spec)

# %%
# Read metadata
df_train = pd.read_csv(path_train_csv)

# %%
df_train
# Out:
#             eeg_id  eeg_sub_id  eeg_label_offset_seconds  spectrogram_id  \
# 0       1628180742           0                       0.0          353733
# 1       1628180742           1                       6.0          353733
# 2       1628180742           2                       8.0          353733
# 3       1628180742           3                      18.0          353733
# 4       1628180742           4                      24.0          353733
# ...            ...         ...                       ...             ...
# 106795   351917269           6                      12.0      2147388374
# 106796   351917269           7                      14.0      2147388374
# 106797   351917269           8                      16.0      2147388374
# 106798   351917269           9                      18.0      2147388374
# 106799   351917269          10                      20.0      2147388374
#
#         spectrogram_sub_id  spectrogram_label_offset_seconds    label_id  \
# 0                        0                               0.0   127492639
# 1                        1                               6.0  3887563113
# 2                        2                               8.0  1142670488
# 3                        3                              18.0  2718991173
# 4                        4                              24.0  3080632009
# ...                    ...                               ...         ...
# 106795                   6                              12.0  4195677307
# 106796                   7                              14.0   290896675
# 106797                   8                              16.0   461435451
# 106798                   9                              18.0  3786213131
# 106799                  10                              20.0  3642716176
#
#         patient_id expert_consensus  seizure_vote  lpd_vote  gpd_vote  \
# 0            42516          Seizure             3         0         0
# 1            42516          Seizure             3         0         0
# 2            42516          Seizure             3         0         0
# 3            42516          Seizure             3         0         0
# 4            42516          Seizure             3         0         0
# ...            ...              ...           ...       ...       ...
# 106795       10351             LRDA             0         0         0
# 106796       10351             LRDA             0         0         0
# 106797       10351             LRDA             0         0         0
# 106798       10351             LRDA             0         0         0
# 106799       10351             LRDA             0         0         0
#
#         lrda_vote  grda_vote  other_vote
# 0               0          0           0
# 1               0          0           0
# 2               0          0           0
# 3               0          0           0
# 4               0          0           0
# ...           ...        ...         ...
# 106795          3          0           0
# 106796          3          0           0
# 106797          3          0           0
# 106798          3          0           0
# 106799          3          0           0
#
# [106800 rows x 15 columns]

# %%
df_spec = pd.read_parquet(spec_files[1])

# %%
df_spec
# Out:
#      time  LL_0.59    LL_0.78    LL_0.98    LL_1.17  LL_1.37    LL_1.56  \
# 0       1     0.51   0.540000   0.520000   0.440000     0.37   0.230000
# 1       3     6.62   8.440000   8.630000   7.770000     7.27   5.810000
# 2       5    14.52  24.900000  24.549999  24.600000    27.67  22.740000
# 3       7    19.66  27.580000  45.419998  25.860001    27.67  44.610001
# 4       9    14.28  16.770000  16.620001  14.760000    13.15   8.970000
# ..    ...      ...        ...        ...        ...      ...        ...
# 303   607     4.98   4.760000   5.240000   6.090000     5.72   5.080000
# 304   609     7.95  13.450000  14.750000  15.810000    14.82  13.140000
# 305   611     8.49  11.330000   8.090000   9.480000     5.57  12.530000
# 306   613    11.71  16.850000  16.860001  13.550000    13.43  24.600000
# 307   615    15.60  19.139999  25.330000  25.389999    19.68  24.020000
#
#        LL_1.76    LL_1.95    LL_2.15  ...  RP_18.16  RP_18.36  RP_18.55  \
# 0     0.210000   0.200000   0.150000  ...      0.00      0.00      0.00
# 1     5.640000   5.660000   5.920000  ...      0.05      0.04      0.04
# 2    18.969999  17.250000  18.230000  ...      0.17      0.11      0.12
# 3    17.200001  15.400000  28.559999  ...      0.19      0.12      0.11
# 4    27.740000  28.740000  29.080000  ...      0.05      0.05      0.05
# ..         ...        ...        ...  ...       ...       ...       ...
# 303   5.980000   5.450000   4.990000  ...      0.14      0.10      0.10
# 304   9.650000   9.600000   6.840000  ...      0.09      0.11      0.13
# 305  13.100000  15.330000  16.250000  ...      0.13      0.15      0.12
# 306  25.100000  25.820000  23.160000  ...      0.12      0.11      0.11
# 307  21.650000  24.709999  14.340000  ...      0.06      0.06      0.05
#
#      RP_18.75  RP_18.95  RP_19.14  RP_19.34  RP_19.53  RP_19.73  RP_19.92
# 0        0.00      0.00      0.00      0.01      0.01      0.02      0.02
# 1        0.04      0.04      0.05      0.05      0.06      0.07      0.07
# 2        0.11      0.08      0.07      0.11      0.10      0.08      0.13
# 3        0.12      0.06      0.09      0.11      0.13      0.14      0.13
# 4        0.03      0.03      0.03      0.02      0.06      0.06      0.07
# ..        ...       ...       ...       ...       ...       ...       ...
# 303      0.12      0.09      0.09      0.11      0.05      0.07      0.06
# 304      0.12      0.12      0.12      0.09      0.10      0.11      0.10
# 305      0.13      0.14      0.08      0.08      0.11      0.09      0.09
# 306      0.13      0.07      0.05      0.06      0.07      0.08      0.08
# 307      0.06      0.02      0.04      0.03      0.04      0.05      0.05
#
# [308 rows x 401 columns]

# %%
df_train_eeg = pd.read_parquet("EEG.parquet")

# %%
df_train_eeg
# Out:
#              Fp1          F3          C3          P3          F7          T3  \
# 0    -105.849998  -89.230003  -79.459999  -49.230000  -99.730003  -87.769997
# 1     -85.470001  -75.070000  -60.259998  -38.919998  -73.080002  -87.510002
# 2       8.840000   34.849998   56.430000   67.970001   48.099998   25.350000
# 3     -56.320000  -37.279999  -28.100000   -2.820000  -43.430000  -35.049999
# 3       7   1.770000   1.930000   1.810000   1.600000   1.430000   1.280000
# 4       9        NaN        NaN        NaN        NaN        NaN        NaN
# ..    ...        ...        ...        ...        ...        ...        ...
# 295   591   2.210000   2.280000   2.200000   1.280000   1.350000   1.930000
# 296   593   2.490000   2.540000   2.150000   1.490000   1.360000   1.570000
# 297   595   0.240000   0.190000   0.210000   0.120000   0.110000   0.080000
# 298   597   0.990000   1.230000   1.370000   1.620000   1.940000   2.190000
# 299   599   1.810000   2.110000   1.950000   1.800000   1.950000   2.120000
#
#        LL_1.76    LL_1.95    LL_2.15  ...  RP_18.16  RP_18.36  RP_18.55  \
# 0    78.480003  63.080002  59.869999  ...      0.13      0.14      0.08
# 1    47.340000  48.599998  40.880001  ...      0.15      0.13      0.08
# 2    27.559999  23.290001  15.120000  ...      0.12      0.11      0.08
# 3     1.190000   1.110000   1.010000  ...      0.03      0.03      0.03
# 4          NaN        NaN        NaN  ...       NaN       NaN       NaN
# ..         ...        ...        ...  ...       ...       ...       ...
# 295   2.300000   2.440000   2.310000  ...      0.03      0.03      0.03
# 296   1.970000   2.050000   1.890000  ...      0.02      0.02      0.02
# 297   0.060000   0.040000   0.040000  ...      0.00      0.00      0.00
# 298   2.270000   2.310000   2.300000  ...      0.02      0.02      0.02
# 299   2.330000   2.450000   2.430000  ...      0.02      0.02      0.02
#
#      RP_18.75  RP_18.95  RP_19.14  RP_19.34  RP_19.53  RP_19.73  RP_19.92
# 0        0.11      0.04      0.03      0.05      0.05      0.04      0.05
# 1        0.08      0.07      0.06      0.07      0.06      0.06      0.06
# 2        0.08      0.09      0.10      0.12      0.14      0.13      0.14
# 3        0.03      0.03      0.03      0.03      0.04      0.04      0.04
# 4         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ..        ...       ...       ...       ...       ...       ...       ...
# 295      0.03      0.03      0.04      0.04      0.03      0.03      0.03
# 296      0.03      0.02      0.02      0.02      0.01      0.01      0.01
# 297      0.01      0.01      0.01      0.01      0.00      0.00      0.00
# 298      0.02      0.02      0.02      0.02      0.01      0.01      0.01
# 299      0.02      0.02      0.02      0.02      0.01      0.01      0.01
#
# [300 rows x 401 columns]

# %% [markdown]
# ## Data Pre-Procssing

# %% [markdown]
# ### Noise Removal - Bandpass Filter
#
# We will use the Butterworth Bandpass Filter to remove noise from the EEG data

# %%
# Function to get Bandpass filter coefficients
def get_filter_Coeff(lowcut, highcut, freq, order):
    nyq_freq = 0.5 * freq # Nyquist Frequency
    low = lowcut / nyq_freq
    high = highcut / nyq_freq
    b, a = butter(order, [low, high], btype='band')
    return b,a


# Function to apply the filter 
def Bandpass_filter(data, lowcut, highcut, freq, order=5):
    b,a = get_filter_Coeff(lowcut, highcut, freq, order)
    fil_sig = lfilter(b, a, data)
    return fil_sig

# %%
lowcut = 1
highcut = 40
freq = 200

filtered_df = df_train_eeg.apply(lambda x: Bandpass_filter(x, lowcut, highcut, freq, order=5))

# %%
filtered_df
# Out:
#             Fp1         F3         C3         P3         F7         T3  \
# ### ICA - Independent Component Analysis
#
# Performing ICA for artifact removal such as eye blinks, heart beats, muscle movements,.etc
#
#
# First, we will transform the dataframe into an array suitable to perform ICA

# %%
import mne
import numpy as np

sfreq = 200  # sampling frequency in Hz
channel_names = filtered_df.columns.tolist()  # Get the column names as channel names
channel_types = ['eeg'] * len(channel_names)  # Assuming all channels are EEG

# Convert DataFrame to numpy array
data = filtered_df.T.to_numpy()  # Transpose because MNE expects channels x times

# Create an MNE Info object
info = mne.create_info(ch_names=channel_names, sfreq=sfreq, ch_types=channel_types)

# Convert to volts (from microvolts, if your data is in uV)
# data = data / 1e6  # Scale if your data is not already in Volts (V)

# Create RawArray
raw = mne.io.RawArray(data, info)
# Out:
# Creating RawArray with float64 data, n_channels=20, n_times=10000
#     Range : 0 ... 9999 =      0.000 ...    49.995 secs
# Ready.

# %%
raw
# Out:
# <RawArray | 20 x 10000 (50.0 s), ~1.5 MB, data loaded>

# %% [markdown]
# #### ICA - (WIP)

# %%
sfreq = raw.info['sfreq']

# Create and fit an ICA model
ica = ICA(n_components=15, random_state=97, max_iter=800)
ica.fit(raw)

# Plot the components to manually identify artifacts
ica.plot_components()
# Out:
# Fitting ICA to data using 20 channels (please be patient, this may take a while)
# Selecting by number: 15 components
# /var/folders/hq/dgkwpqzd10xgjv9hflydy7tm0000gn/T/ipykernel_13258/1488532871.py:7: RuntimeWarning: The data has not been high-pass filtered. For good ICA performance, it should be high-pass filtered (e.g., with a 1.0 Hz lower bound) before fitting ICA.
#   ica.fit(raw)
# Fitting ICA took 0.3s.
# WARNING:root:Did not find any electrode locations (in the info object), will attempt to use digitization points instead. However, if digitization points do not correspond to the EEG electrodes, this will lead to bad results. Please verify that the sensor locations in the plot are accurate.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 10
#       7 ica.fit(raw)
#       9 # Plot the components to manually identify artifacts
# ---> 10 ica.plot_components()
#
# File ~/anaconda3/lib/python3.11/site-packages/mne/preprocessing/ica.py:2473, in ICA.plot_components(self, picks, ch_type, inst, plot_std, reject, sensors, show_names, contours, outlines, sphere, image_interp, extrapolate, border, res, size, cmap, vlim, cnorm, colorbar, cbar_fmt, axes, title, nrows, ncols, show, image_args, psd_args, verbose)
#    2440 @copy_function_doc_to_method_doc(plot_ica_components)
#    2441 def plot_components(
#    2442     self,
#    (...)
#    2471     verbose=None,
#    2472 ):
# -> 2473     return plot_ica_components(
#    2474         self,
#    2475         picks=picks,
#    2476         ch_type=ch_type,
#    2477         inst=inst,
#    2478         plot_std=plot_std,
#    2479         reject=reject,
#    2480         sensors=sensors,
#    2481         show_names=show_names,
#    2482         contours=contours,
#    2483         outlines=outlines,
#    2484         sphere=sphere,
#    2485         image_interp=image_interp,
#    2486         extrapolate=extrapolate,
#    2487         border=border,
#    2488         res=res,
#    2489         size=size,
#    2490         cmap=cmap,
#    2491         vlim=vlim,
#    2492         cnorm=cnorm,
#    2493         colorbar=colorbar,
#    2494         cbar_fmt=cbar_fmt,
#    2495         axes=axes,
#    2496         title=title,
#    2497         nrows=nrows,
#    2498         ncols=ncols,
#    2499         show=show,
#    2500         image_args=image_args,
#    2501         psd_args=psd_args,
#    2502         verbose=verbose,
#    2503     )
#
# File <decorator-gen-137>:12, in plot_ica_components(ica, picks, ch_type, inst, plot_std, reject, sensors, show_names, contours, outlines, sphere, image_interp, extrapolate, border, res, size, cmap, vlim, cnorm, colorbar, cbar_fmt, axes, title, nrows, ncols, show, image_args, psd_args, verbose)
#
# File ~/anaconda3/lib/python3.11/site-packages/mne/viz/topomap.py:1651, in plot_ica_components(ica, picks, ch_type, inst, plot_std, reject, sensors, show_names, contours, outlines, sphere, image_interp, extrapolate, border, res, size, cmap, vlim, cnorm, colorbar, cbar_fmt, axes, title, nrows, ncols, show, image_args, psd_args, verbose)
#    1640 except TypeError:  # None or Axes
#    1641     _axes = axes
#    1643 (
#    1644     data_picks,
#    1645     pos,
#    1646     merge_channels,
#    1647     names,
#    1648     ch_type,
#    1649     sphere,
#    1650     clip_origin,
# -> 1651 ) = _prepare_topomap_plot(ica, ch_type, sphere=sphere)
#    1653 cmap = _setup_cmap(cmap, n_axes=len(picks))
#    1654 names = _prepare_sensor_names(names, show_names)
#
# File ~/anaconda3/lib/python3.11/site-packages/mne/viz/topomap.py:134, in _prepare_topomap_plot(inst, ch_type, sphere)
#     131 info._check_consistency()
#     133 # special case for merging grad channels
# --> 134 layout = find_layout(info)
#     135 if (
#     136     ch_type == "grad"
#     137     and layout is not None
#    (...)
#     141     )
#     142 ):
#     143     picks, _ = _pair_grad_sensors(info, layout)
#
# File ~/anaconda3/lib/python3.11/site-packages/mne/channels/layout.py:507, in find_layout(info, ch_type, exclude)
#     502     if not isinstance(info, (dict, Info)):
#     503         raise RuntimeError(
#     504             "Cannot make EEG layout, no measurement info "
#     505             "was passed to `find_layout`"
#     506         )
# --> 507     return make_eeg_layout(info, exclude=exclude)
#     508 elif has_csd_coils and ch_type in [None, "csd"]:
#     509     return make_eeg_layout(info, exclude=exclude, csd=True)
#
# File ~/anaconda3/lib/python3.11/site-packages/mne/channels/layout.py:327, in make_eeg_layout(info, radius, width, height, exclude, csd)
#     325     pick_kwargs.update(csd=True, eeg=False)
#     326 picks = pick_types(info, **pick_kwargs)
# --> 327 loc2d = _find_topomap_coords(info, picks)
#     328 names = [info["chs"][i]["ch_name"] for i in picks]
#     330 # Scale [x, y] to be in the range [-0.5, 0.5]
#     331 # Don't mess with the origin or aspect ratio
#
# File ~/anaconda3/lib/python3.11/site-packages/mne/channels/layout.py:738, in _find_topomap_coords(info, picks, layout, ignore_overlap, to_sphere, sphere)
#     736     pos = np.asarray(pos)
#     737 else:
# --> 738     pos = _auto_topomap_coords(
#     739         info,
#     740         picks,
#     741         ignore_overlap=ignore_overlap,
#     742         to_sphere=to_sphere,
#     743         sphere=sphere,
#     744     )
#     746 return pos
#
# File ~/anaconda3/lib/python3.11/site-packages/mne/channels/layout.py:811, in _auto_topomap_coords(info, picks, ignore_overlap, to_sphere, sphere)
#     809 # Get EEG digitization points
#     810 if info["dig"] is None or len(info["dig"]) == 0:
# --> 811     raise RuntimeError("No digitization points found.")
#     813 locs3d = np.array(
#     814     [
#     815         point["r"]
#    (...)
#     818     ]
#     819 )
#     821 if len(locs3d) == 0:
#
# RuntimeError: No digitization points found.

# %% [markdown]
# ## Feature Extraction

# %% [markdown]
# #### Power Spectral Density - time domain

# %% [markdown]
# #### FFT - Frequency domain

# %% [markdown]
# #### Waveform - Time-Frequency Domain

# %% [markdown]
# ## Modelling
#
# Based on the type of the Feature Extracted, the following models will be trained on the respective features and an ensemble of these models will be created for prediction/inference.
#
# The models will be evaluated on the `Kullback Liebler divergence` Metric
#
# **Predictive Models** :
#
# 1) CNN for FFT
# 2) LSTM for Power Spectral Density
# 3) Wavenets for Waveforms

# %%
torch.cuda.is_available()
# Out:
# False
